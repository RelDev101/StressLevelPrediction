# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd

df = pd.read_csv("../data/SaYoPillow.csv")

df
# Out:
#          sr      rr       t      lm      bo     rem   sr.1     hr  sl
# 0    93.800  25.680  91.840  16.600  89.840   99.60  1.840  74.20   3
# 1    91.640  25.104  91.552  15.880  89.552   98.88  1.552  72.76   3
# 2    60.000  20.000  96.000  10.000  95.000   85.00  7.000  60.00   1
# 3    85.760  23.536  90.768  13.920  88.768   96.92  0.768  68.84   3
# 4    48.120  17.248  97.872   6.496  96.248   72.48  8.248  53.12   0
# ..      ...     ...     ...     ...     ...     ...    ...    ...  ..
# 625  69.600  20.960  92.960  10.960  90.960   89.80  3.440  62.40   2
# 626  48.440  17.376  98.064   6.752  96.376   73.76  8.376  53.44   0
# 627  97.504  27.504  86.880  17.752  84.256  101.88  0.000  78.76   4
# 628  58.640  19.728  95.728   9.728  94.592   84.32  6.728  59.32   1
# 629  73.920  21.392  93.392  11.392  91.392   91.96  4.088  63.48   2
#
# [630 rows x 9 columns]

# %%
df.rename(columns={'sr': 'snoring rate', 
                   'rr':'respiration rate', 
                   't': 'body temperature', 
                   'lm':'limb movement',
                   'bo':'blood oxygen', 
                   'rem':'eye movement rate', 
                   'sr.1':'sleeping hours', 
                   'hr':'heart rate',
                   'sl':'stress levels'}, inplace=True)

df
# Out:
#      snoring rate  respiration rate  body temperature  limb movement  \
# 0          93.800            25.680            91.840         16.600
# 1          91.640            25.104            91.552         15.880
# 2          60.000            20.000            96.000         10.000
# 3          85.760            23.536            90.768         13.920
# 4          48.120            17.248            97.872          6.496
# ..            ...               ...               ...            ...
# 625        69.600            20.960            92.960         10.960
# 626        48.440            17.376            98.064          6.752
# 627        97.504            27.504            86.880         17.752
# 628        58.640            19.728            95.728          9.728
# 629        73.920            21.392            93.392         11.392
#
#      blood oxygen  eye movement rate  sleeping hours  heart rate  \
# 0          89.840              99.60           1.840       74.20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   snoring rate       630 non-null    float64
#  1   respiration rate   630 non-null    float64
#  2   body temperature   630 non-null    float64
#  3   limb movement      630 non-null    float64
#  4   blood oxygen       630 non-null    float64
#  5   eye movement rate  630 non-null    float64
#  6   sleeping hours     630 non-null    float64
#  7   heart rate         630 non-null    float64
#  8   stress levels      630 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 44.4 KB

# %%
df.describe()
# Out:
#        snoring rate  respiration rate  body temperature  limb movement  \
# count    630.000000        630.000000         630.00000     630.000000
# mean      71.600000         21.800000          92.80000      11.700000
# std       19.372833          3.966111           3.52969       4.299629
# min       45.000000         16.000000          85.00000       4.000000
# 25%       52.500000         18.500000          90.50000       8.500000
# 50%       70.000000         21.000000          93.00000      11.000000
# 75%       91.250000         25.000000          95.50000      15.750000
# max      100.000000         30.000000          99.00000      19.000000
#
#        blood oxygen  eye movement rate  sleeping hours  heart rate  \
# count    630.000000         630.000000      630.000000  630.000000
# mean      90.900000          88.500000        3.700000   64.500000
# std        3.902483          11.893747        3.054572    9.915277
# ...

# %%
df.isnull().sum()
# Out:
# snoring rate         0
# respiration rate     0
# body temperature     0
# limb movement        0
# blood oxygen         0
# eye movement rate    0
# sleeping hours       0
# heart rate           0
# stress levels        0
# dtype: int64

# %%
df['stress levels'].value_counts()
# Out:
# stress levels
# 3    126
# 1    126
# 0    126
# 2    126
# 4    126
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='stress levels', data=df)
plt.title('Distribusi Stress Levels')
plt.show()
